# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn


n_majority = 100000

# The desired mean values of the sample.
mu = np.array([5,5,5,5,5,5])

# The desired covariance matrix.
r = np.array([
        [1,0,-0.07,0.31,-0.069,0.65],
[0,1,0,0,0.258,0.1],
[-0.07,0,1,0.71,0.012,0.16],
[0.31,0,0.71,1,0.17,0.58],
[-0.069,0.258,0.012,0.17,1,0.22],
[0.65,0.1,0.16,0.58,0.22,1]
    ])

# Generate the random samples.
rng = np.random.default_rng()
y = rng.multivariate_normal(mu, r, size=n_majority)

# %%
dataset = pd.DataFrame(y)
dataset['group'] = 0

# %%
dataset.describe()
# Out:
#                    0              1              2              3  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        4.997525       5.002561       5.001161       5.001861
# std         0.996670       0.999384       1.000360       1.001422
# min         0.531289       0.828278       0.454884       0.691540
# 25%         4.327496       4.331956       4.327505       4.330912
# 50%         4.996989       5.003103       4.999217       5.005006
# 75%         5.668808       5.673080       5.675384       5.675730
# max         9.205868       9.272268       9.106481       9.030680
#
#                    4              5     group
# count  100000.000000  100000.000000  100000.0
# mean        5.002725       4.998443       0.0
# std         1.001108       0.999659       0.0
# min         0.683809       0.754481       0.0
# 25%         4.327047       4.326127       0.0
# 50%         5.000766       4.998543       0.0
# 75%         5.673037       5.675776       0.0
# max         9.775769       9.136052       0.0

# %%
dataset.corr()
# Out:
#               0         1         2         3         4         5  group
# 0      1.000000  0.000617 -0.069301  0.310634 -0.071734  0.646288    NaN
# 1      0.000617  1.000000 -0.001701  0.000961  0.259331  0.101372    NaN
# 2     -0.069301 -0.001701  1.000000  0.708933  0.013948  0.160550    NaN
# 3      0.310634  0.000961  0.708933  1.000000  0.173497  0.582095    NaN
# 4     -0.071734  0.259331  0.013948  0.173497  1.000000  0.222684    NaN
# 5      0.646288  0.101372  0.160550  0.582095  0.222684  1.000000    NaN
# group       NaN       NaN       NaN       NaN       NaN       NaN    NaN

# %%
corrMatrix = dataset.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
#effect sizes between black and white
d = [0.72,0,0,0.31,0,0]
minority_proportion = .135
minority_n = round((n_majority*minority_proportion)/(1-minority_proportion))
minority_means = mu - d

# %%
minority_means = mu - d

# %%
rng = np.random.default_rng()
y = rng.multivariate_normal(minority_means, r, size=minority_n)

# %%
minority = pd.DataFrame(y)
minority['group'] = 1

# %%
minority.describe()
# Out:
#                   0             1             2             3             4  \
# count  15607.000000  15607.000000  15607.000000  15607.000000  15607.000000
# mean       4.289973      5.008605      4.986943      4.683977      4.996136
# std        1.002340      0.999840      0.992314      0.992246      0.998817
# min        0.389816      1.618867      1.196765      0.989107      0.800134
# 25%        3.614129      4.332975      4.313988      4.013962      4.334434
# 50%        4.292315      5.005027      4.979500      4.681775      4.995327
# 75%        4.957895      5.683961      5.661411      5.349909      5.667923
# max        7.843895      9.408120      8.626239      9.127501      8.695707
#
#                   5    group
# count  15607.000000  15607.0
# mean       5.005390      1.0
# std        1.001491      0.0
# min        1.267312      1.0
# 25%        4.334862      1.0
# 50%        5.003208      1.0
# 75%        5.672775      1.0
# max        9.397566      1.0

# %%
data = minority.append(dataset)

# %%
data.describe()
# Out:
#                    0              1              2              3  \
# count  115607.000000  115607.000000  115607.000000  115607.000000
# mean        4.902005       5.003377       4.999242       4.958947
# std         1.026321       0.999443       0.999285       1.006065
# min         0.389816       0.828278       0.454884       0.691540
# 25%         4.216413       4.332148       4.325475       4.283136
# 50%         4.906598       5.003464       4.996693       4.962317
# 75%         5.594606       5.674798       5.673516       5.635715
# max         9.205868       9.408120       9.106481       9.127501
#
#                    4              5          group
# count  115607.000000  115607.000000  115607.000000
# mean        5.001836       4.999381       0.135000
# std         1.000797       0.999905       0.341726
# min         0.683809       0.754481       0.000000
# 25%         4.327850       4.327340       0.000000
# 50%         4.999604       4.999057       0.000000
# 75%         5.672197       5.675267       0.000000
# max         9.775769       9.397566       1.000000

# %%
data = data.rename(columns={0:'Cognitive Ability',1:'Education',2:'Experience',3:'Structured Interview',4:'Conscientiousness',5:'Performance'})

# %%
from pathlib import Path  
filepath = Path('sim_AI_dataset.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
data.to_csv(filepath)

# %%
data
# Out:
#        Cognitive Ability  Education  Experience  Structured Interview  \
# 0               3.773517   4.543722    5.591037              5.788898
# 1               5.959783   5.399290    4.738243              3.971467
# 2               5.053876   4.224994    3.351490              4.251340
# 3               3.329378   5.774108    5.907130              3.357350
# 4               4.222713   5.235311    3.814666              3.296356
# ...                  ...        ...         ...                   ...
# 99995           4.606004   6.272019    4.377818              4.056900
# 99996           5.820410   4.532283    3.739426              5.054115
# 99997           4.430423   5.659989    3.069073              3.448636
# 99998           4.815454   4.277386    6.464627              6.358807
# 99999           4.037252   4.277637    5.727007              4.809211
#
#        Conscientiousness  Performance  group
# 0               4.051469     5.252405      1
# 1               4.632391     4.575094      1
# 2               2.814327     5.075309      1
# 3               5.504136     4.233734      1
# 4               4.605360     5.361654      1
# ...                  ...          ...    ...
# 99995           5.377892     4.715318      0
# 99996           5.475876     6.539127      0
# 99997           3.394717     4.832527      0
# 99998           3.529500     4.947332      0
# 99999           4.151917     4.784662      0
#
# [115607 rows x 7 columns]
